# %% [markdown]
# <a href="https://colab.research.google.com/github/darapanenichandana/my-app/blob/main/webscraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def search(query):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"
    }

    search_url = f"https://www.bing.com/search?q={query.replace(' ', '+')}"
    response = requests.get(search_url, headers=headers)

    if response.status_code != 200:
        print("Error fetching search results")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    results = soup.find_all("li", class_="b_algo", limit=6)

    if not results:
        print("No results found")
        return None

    data = []

    for result in results:
        title = result.find("h2").text if result.find("h2") else "No title"
        link = result.find("a")["href"] if result.find("a") else "No link"
        description = result.find("p").text if result.find("p") else "No description"

        data.append({"Title": title, "Link": link, "Description": description})


    df = pd.DataFrame(data)
    return df


query = "recent movies"
df_results = search(query)


if df_results is not None:
    print(df_results)


df_results
# Out:
#                                                Title  \
# 0  New Movies Out Now in Theaters (2025) - Rotten...
# 1   New Movies Out Now & In Theaters 2025 | Fandango
# 2               15 Best Movies in Theaters Right Now
# 3  Movies Out Now - In Theaters & Streaming - Mov...
# 4  The 10 Best Movies in Theaters Right Now - Scr...
# 5                New Movies In Theaters - Metacritic
#
#                                                 Link  \
# 0  https://www.rottentomatoes.com/browse/movies_i...
# 1        https://www.fandango.com/movies-in-theaters
# 2  https://movieweb.com/best-movies-right-now-in-...
# 3  https://www.movieinsider.com/lists/movies-out-...
# 4  https://screenrant.com/best-movies-in-theaters...
# 5  https://www.metacritic.com/browse/movie/?relea...
#
#                                          Description
# 0  Rotten Tomatoes, home of the Tomatometer, is t...
# 1  Discover new movies in 2025. Stay updated with...
# 2                                     No description
# ...
