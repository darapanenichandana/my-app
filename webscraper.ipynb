# %% [markdown]
# <a href="https://colab.research.google.com/github/darapanenichandana/my-app/blob/main/webscraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def search(query):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"
    }

    search_url = f"https://www.bing.com/search?q={query.replace(' ', '+')}"
    response = requests.get(search_url, headers=headers)

    if response.status_code != 200:
        print("Error fetching search results")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    results = soup.find_all("li", class_="b_algo", limit=5)

    if not results:
        print("No results found")
        return None

    data = []

    for result in results:
        title = result.find("h2").text if result.find("h2") else "No title"
        link = result.find("a")["href"] if result.find("a") else "No link"
        description = result.find("p").text if result.find("p") else "No description"

        data.append({"Title": title, "Link": link, "Description": description})


    df = pd.DataFrame(data)
    return df

query = "recent sports"
df_results = search(query)


if df_results is not None:
    print(df_results)

df_results
# Out:
#                                                Title  \
# 0  The Latest Sports News, Updates & Articles | F...
# 1  Sports News, Scores, Predictions and Analysis ...
# 2                          Latest Sports News - ESPN
# 3  Sports: Latest Sports News & Sports Articles |...
# 4    Sporting News - NFL | NBA | MLB | NCAA | Boxing
#
#                                    Link  \
# 0        https://www.foxnews.com/sports
# 1      https://www.usatoday.com/sports/
# 2  https://www.espn.com/espn/latestnews
# 3             https://apnews.com/sports
# 4         https://www.sportingnews.com/
#
#                                          Description
# 0  Check out trending sports news with Fox News. ...
# 1  USA TODAY provides the latest sports news, sco...
# 2  A compilation of the latest sports news from E...
# 3  Get the latest sports news from The Associated...
# 4  The latest news, videos, scores and more on th...
#                                                Title  \
# 0  The Latest Sports News, Updates & Articles | F...
# 1  Sports News, Scores, Predictions and Analysis ...
# 2                          Latest Sports News - ESPN
# 3  Sports: Latest Sports News & Sports Articles |...
# 4    Sporting News - NFL | NBA | MLB | NCAA | Boxing
#
#                                    Link  \
# 0        https://www.foxnews.com/sports
# 1      https://www.usatoday.com/sports/
# 2  https://www.espn.com/espn/latestnews
# 3             https://apnews.com/sports
# 4         https://www.sportingnews.com/
#
#                                          Description
# 0  Check out trending sports news with Fox News. ...
# 1  USA TODAY provides the latest sports news, sco...
# 2  A compilation of the latest sports news from E...
# 3  Get the latest sports news from The Associated...
# 4  The latest news, videos, scores and more on th...
