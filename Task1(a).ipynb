# %% [markdown]
# <a href="https://colab.research.google.com/github/darapanenichandana/my-app/blob/main/Task1(a).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



file_path = '/content/datatableontask1.csv'
data = pd.read_csv(file_path)

print("📄 First 5 Rows of the Dataset:")
print(data.head())

print("\n Dataset Information:")
print(data.info())


print("\n Missing Values in Each Column:")
print(data.isnull().sum())


print("\n Summary Statistics:")
print(data.describe())

if 'Sales' in data.columns:
    average_sales = data['Sales'].mean()
    print(f"\n Average Sales: {average_sales}")
else:
    print("\n'Sales' column not found in the dataset!")

if 'Profit' in data.columns:
    average_profit = data['Profit'].mean()
    print(f" Average Profit: {average_profit}")
else:
    print("\n'Profit' column not found in the dataset!")


data.fillna(0, inplace=True)

plt.figure(figsize=(10, 6))
if 'Category' in data.columns and 'Sales' in data.columns:
    sns.barplot(x='Category', y='Sales', data=data, palette='viridis')
    plt.title('Sales by Category')
    plt.xlabel('Category')
    plt.ylabel('Sales')
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.savefig('bar_chart.png')
    plt.show()
else:
    print("Missing 'Category' or 'Sales' columns.")


plt.figure(figsize=(10, 6))
if 'Profit' in data.columns and 'Sales' in data.columns:
    sns.scatterplot(x='Profit', y='Sales', data=data, hue='Category', palette='Set2', s=100)
    plt.title('Profit vs Sales')
    plt.xlabel('Profit')
    plt.ylabel('Sales')
    plt.grid(linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.savefig('scatter_plot.png')
    plt.show()
else:
    print("Missing 'Profit' or 'Sales' columns.")


plt.figure(figsize=(12, 10))
numeric_data = data.select_dtypes(include='number')
if not numeric_data.empty:
    corr_matrix = numeric_data.corr()
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
    plt.title('Correlation Heatmap')
    plt.tight_layout()
    plt.savefig('heatmap.png')
    plt.show()
else:
    print("No numeric data for heatmap.")


import time
for file_name in ['bar_chart.png', 'scatter_plot.png', 'heatmap.png']:
    time.sleep(1)
    files.download(file_name)
# Out:
# 📄 First 5 Rows of the Dataset:
#   Product     Category  Sales  Profit
# 0  Laptop  Electronics   1500     200
# 1   Phone  Electronics   1200     180
# 2   Shoes      Fashion    800     100
# 3   Shirt      Fashion    400      50
# 4    Book    Education    300      70
#
#  Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   5 non-null      object
#  1   Category  5 non-null      object
#  2   Sales     5 non-null      int64
#  3   Profit    5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
# None
#
#  Missing Values in Each Column:
# Product     0
# Category    0
# Sales       0
# Profit      0
# dtype: int64
#
#  Summary Statistics:
#              Sales     Profit
# count     5.000000    5.00000
# mean    840.000000  120.00000
# std     512.835256   66.70832
# ...
